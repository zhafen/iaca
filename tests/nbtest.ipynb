# %%
import os

# %%
import pandas as pd
import networkx as nx

# %%
from iaca import data, etl, sketch, transform
from iaca.extract import extract_python, extract_yaml
from iaca import system_tests

# %%
# DEBUG
import importlib

importlib.reload(data)
importlib.reload(extract_yaml)
importlib.reload(extract_python)
importlib.reload(etl)
importlib.reload(transform)
importlib.reload(system_tests)
importlib.reload(sketch)
# Out:
# <module 'iaca.sketch' from '/Users/zhafen/repos/iaca/iaca/sketch.py'>

# %%
architect = sketch.Architect(root_dir="..")
registry = architect.perform_registry_etl()
tests, test_results = architect.validate_registry(
    min_priority=0.5,
    allowed_infrastructure=["iaca_infrastructure"],
)
# Out:
# /Users/zhafen/repos/iaca/.venv/lib/python3.13/site-packages/pandera/backends/pandas/container.py:569: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# entity: iaca/system_tests.test_designed
# requirement: fully_designed
# priority: 0.9
# description:
#     Each [requirement] entity has at least one [satisfies] entity or one [child]
#     entity.
# test_passed: False
# failed_components:
#                                        entity requirement.comp_key  \
# 1           can_budget_for_preference_and_fit                    1
# 5                  can_build_requirements_map                    1
# 6      can_calculate_the_most_efficient_paths                    1
# 7                      can_document_workflows                    1
# 12                   compatible_with_a_config                    1
# 13      compliments_existing_agile_approaches                    1
# 14                      directly_calls_agents                    1
# 18  enables_reconciliation_via_postprocessing                    1
# 19              facilitates_a_source_of_truth                    0
# 25                          has_an_mcp_server                    1
# 46                       supports_easy_lookup                    1
# 47                            syntax_is_brief                    0
# 48                         syntax_is_flexible                    1
#
#     requirement.priority    requirement.value link.link_type link.source  \
# 1                    0.5  iaca_infrastructure            NaN         NaN
# 5                    0.9  iaca_infrastructure            NaN         NaN
# 6                    0.5  iaca_infrastructure            NaN         NaN
# 7                    0.5                  NaN            NaN         NaN
# 12                   0.5  iaca_infrastructure            NaN         NaN
# 13                   0.5  iaca_infrastructure            NaN         NaN
# 14                   0.5  iaca_infrastructure            NaN         NaN
# 18                   0.7  iaca_infrastructure            NaN         NaN
# 19                   0.5  iaca_infrastructure            NaN         NaN
# 25                   0.5  iaca_infrastructure            NaN         NaN
# 46                   0.5                  NaN            NaN         NaN
# 47                   0.5  iaca_infrastructure            NaN         NaN
# 48                   0.5  iaca_infrastructure            NaN         NaN
#
#    link.target status.comp_key status.value test.comp_key test.value
# 1          NaN             NaN          NaN           NaN        NaN
# 5          NaN             NaN          NaN           NaN        NaN
# 6          NaN             NaN          NaN           NaN        NaN
# 7          NaN             NaN          NaN           NaN        NaN
# 12         NaN             NaN          NaN           NaN        NaN
# 13         NaN             NaN          NaN           NaN        NaN
# 14         NaN             NaN          NaN           NaN        NaN
# 18         NaN             NaN          NaN           NaN        NaN
# 19         NaN             NaN          NaN           NaN        NaN
# 25         NaN             NaN          NaN           NaN        NaN
# 46         NaN             NaN          NaN           NaN        NaN
# 47         NaN             NaN          NaN           NaN        NaN
# 48         NaN             NaN          NaN           NaN        NaN
# --------------------------------------------------------------------------------
#
# entity: iaca/system_tests.test_defined
# requirement: fully_defined
# priority: 0.8
# description:
#     All [compdef] entities are defined and valid.
# test_passed: False
# failed_components:
#                comp_key multiplicity  normalize unparsed_fields  is_defined  \
# entity
# specifications        0         0..*       True              {}       False
#
#                                                            fields  is_valid  \
# entity
# specifications  {'entity': <Schema Field(name=entity, type=Dat...     False
#
#                                                errors
# entity
# specifications  Component definition does not exist.
# --------------------------------------------------------------------------------
#
# entity: iaca/system_tests.test_implemented
# requirement: fully_implemented
# priority: 0.7
# description:
#     Meets the same criteria as "fully_designed" and all [satisfies] entities
#     either have a test that passes when executed or have a status of "in
#     production".
# test_passed: False
# failed_components:
#                                        entity requirement.comp_key  \
# 0         accepts_nested_entities_as_children                    1
# 1           can_budget_for_preference_and_fit                    1
# 5                  can_build_requirements_map                    1
# 6      can_calculate_the_most_efficient_paths                    1
# 7                      can_document_workflows                    1
# 11                   can_perform_registry_etl                    1
# 12                   compatible_with_a_config                    1
# 13      compliments_existing_agile_approaches                    1
# 14                      directly_calls_agents                    1
# 18  enables_reconciliation_via_postprocessing                    1
# 19              facilitates_a_source_of_truth                    0
# 25                          has_an_mcp_server                    1
# 44    stores_manifest_data_in_a_useful_format                    1
# 45    stores_manifest_data_in_a_useful_format                    1
# 46                       supports_easy_lookup                    1
# 47                            syntax_is_brief                    0
# 48                         syntax_is_flexible                    1
#
#     requirement.priority    requirement.value link.link_type  \
# 0                    0.9  iaca_infrastructure      satisfies
# 1                    0.5  iaca_infrastructure            NaN
# 5                    0.9  iaca_infrastructure            NaN
# 6                    0.5  iaca_infrastructure            NaN
# 7                    0.5                  NaN            NaN
# 11                   0.5                  NaN      satisfies
# 12                   0.5  iaca_infrastructure            NaN
# 13                   0.5  iaca_infrastructure            NaN
# 14                   0.5  iaca_infrastructure            NaN
# 18                   0.7  iaca_infrastructure            NaN
# 19                   0.5  iaca_infrastructure            NaN
# 25                   0.5  iaca_infrastructure            NaN
# 44                   0.5  iaca_infrastructure      satisfies
# 45                   0.5  iaca_infrastructure      satisfies
# 46                   0.5                  NaN            NaN
# 47                   0.5  iaca_infrastructure            NaN
# 48                   0.5  iaca_infrastructure            NaN
#
#                                           link.source  \
# 0   iaca/extract/extract_yaml.YAMLExtractor.parse_...
# 1                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 11                               perform_registry_etl
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 18                                                NaN
# 19                                                NaN
# 25                                                NaN
# 44                            manifest_in_docstore_db
# 45                          manifest_in_relational_db
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
#
#                                 link.target status.comp_key status.value  \
# 0       accepts_nested_entities_as_children             NaN          NaN
# 1                                       NaN             NaN          NaN
# 5                                       NaN             NaN          NaN
# 6                                       NaN             NaN          NaN
# 7                                       NaN             NaN          NaN
# 11                 can_perform_registry_etl             NaN          NaN
# 12                                      NaN             NaN          NaN
# 13                                      NaN             NaN          NaN
# 14                                      NaN             NaN          NaN
# 18                                      NaN             NaN          NaN
# 19                                      NaN             NaN          NaN
# 25                                      NaN             NaN          NaN
# 44  stores_manifest_data_in_a_useful_format             NaN          NaN
# 45  stores_manifest_data_in_a_useful_format             NaN          NaN
# 46                                      NaN             NaN          NaN
# 47                                      NaN             NaN          NaN
# 48                                      NaN             NaN          NaN
#
#    test.comp_key test.value
# 0            NaN        NaN
# 1            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN
# 18           NaN        NaN
# 19           NaN        NaN
# 25           NaN        NaN
# 44           NaN        NaN
# 45           NaN        NaN
# 46           NaN        NaN
# 47           NaN        NaN
# 48           NaN        NaN
# --------------------------------------------------------------------------------
#
# entity: iaca/system_tests.test_no_forbidden_components
# requirement: no_forbidden_components
# priority: 0.5
# description:
#     No [error], [todo], or other "forbidden" components.
# test_passed: False
# failed_components:
#                                                entity comp_key  \
# 0                                         FunctionDef        4
# 1                                              Module        2
# 2                                               child        4
# 3                                     child_component        1
# 4                                           component        5
# 5                                           component        6
# 6                                       documentation        3
# 7                                        foreign_keys        3
# 8                      iaca/data.Registry.__getitem__        0
# 9                         iaca/data.Registry.__init__        0
# 10    iaca/etl.TransformSystem.build_graph_from_links        0
# 11      iaca/etl.TransformSystem.normalize_components        0
# 12                     iaca/sketch.Architect.__init__        0
# 13         iaca/sketch.Architect.perform_registry_etl        2
# 14            iaca/sketch.Architect.validate_registry        3
# 15            iaca/sketch.Architect.validate_registry        4
# 16            iaca/sketch.Architect.validate_registry        5
# 17            iaca/sketch.Architect.validate_registry        6
# 18            iaca/sketch.Architect.validate_registry        7
# 19                 iaca/system_tests.test_implemented        2
# 20     iaca/system_tests.test_no_forbidden_components        2
# 21  iaca/transform/preprocess.ComponentNormalizer....        0
# 22       iaca/transform/preprocess.ComponentValidator        0
# 23                                          link_type        3
# 24                                             parent        4
# 25                                        requirement        4
# 26                                 validate_compinsts        3
# 27                                             fields        2
#
#                                                 value
# 0   Allow components to be defined in the doc stri...
# 1   Reconcile the paths s.t. we can easily and acc...
# 2   Currently child links are used for both specif...
# 3   Consider if we can roll this up into a more ge...
# 4   Can we condense the formatting for multiple co...
# 5   Can we allow entities to be defined inside oth...
# 6   The value of documentation is a path, so it sh...
# 7     The logic to parse this is not yet implemented.
# 8   We could return an empty DataFrame with a defi...
# 9   Something about initializing with a parameter_...
# 10  Probably delete this, because it makes more se...
# 11  Don't hardcode the skip_normalization list her...
# 12  There should be no parameters that aren't in t...
# 13  Point to the unit test for this, instead of ch...
# 14  Point to the unit test for this, instead of ch...
# 15  Currently we're only set up to run tests that ...
# 16  Tests that are imported as Python code are cur...
# 17  Is this function suffering from trying to be t...
# 18  The errors are often mangled. For example, a K...
# 19  Add code that identifies parent nodes with uns...
# 20                               Add priority cutoff.
# 21  The way this is set up currently, no component...
# 22  Add validation that warns users when they try ...
# 23  Get rid of reverse relations and just use the ...
# 24  Reverse this with child, since that produces a...
# 25  I think it's pretty confusing to have requirem...
# 26                            Update to use pydantic.
# 27  Parsing fails if the user doesn't specify the ...
# --------------------------------------------------------------------------------

# %%
min_priority = 0.5
reqs = registry.view(["requirement", "description", "status"])
reqs = reqs.loc[reqs["requirement.priority"] >= min_priority]
reqs
# Out:
#                                                requirement.comp_key  \
# entity
# accepts_nested_entities_as_children                               1
# can_budget_for_preference_and_fit                                 1
# can_build_delivery_plan                                           1
# can_build_requirements_map                                        1
# can_calculate_the_most_efficient_paths                            1
# can_document_workflows                                            1
# can_execute_tests                                                 1
# can_incorporate_poorly_formed_components                          1
# can_perform_registry_etl                                          1
# compatible_with_a_config                                          1
# compliments_existing_agile_approaches                             1
# directly_calls_agents                                             1
# documentation_coverage_is_high                                    5
# documentation_quality_is_high                                     1
# documentation_uses_consistent_perspective                         1
# documentation_uses_consistent_terminology                         1
# documents_system_architecture                                     1
# draws_on_widely_used_system_design_terminology                    1
# enables_iterative_system_decomposition                            1
# enables_reconciliation_via_postprocessing                         1
# facilitates_a_source_of_truth                                     0
# facilitates_system_design                                         0
# fully_defined                                                     1
# fully_designed                                                    1
# fully_implemented                                                 1
# has_a_good_name                                                   1
# has_an_mcp_server                                                 1
# has_good_documentation                                            1
# has_good_syntax                                                   1
# implements_systems                                                0
# is_a_useful_tool                                                  1
# is_marketable                                                     1
# minimizes_structure_repetition                                    1
# no_forbidden_components                                           1
# reconciles_user_components                                        1
# records_system_architecture                                       0
# stores_manifest_data_in_a_useful_format                           1
# supports_easy_lookup                                              1
# syntax_is_brief                                                   0
# syntax_is_flexible                                                1
# terminology_is_externally_consistent                              1
# terminology_is_internally_consistent                              1
# uses_consistent_ecs_terminology                                   1
# validates_system_architecture                                     1
# works_with_llms_to_implement_systems                              1
#
#                                                 requirement.priority  \
# entity
# accepts_nested_entities_as_children                              0.9
# can_budget_for_preference_and_fit                                0.5
# can_build_delivery_plan                                          0.5
# can_build_requirements_map                                       0.9
# can_calculate_the_most_efficient_paths                           0.5
# can_document_workflows                                           0.5
# can_execute_tests                                                0.5
# can_incorporate_poorly_formed_components                         0.5
# can_perform_registry_etl                                         0.5
# compatible_with_a_config                                         0.5
# compliments_existing_agile_approaches                            0.5
# directly_calls_agents                                            0.5
# documentation_coverage_is_high                                   0.5
# documentation_quality_is_high                                    0.5
# documentation_uses_consistent_perspective                        0.5
# documentation_uses_consistent_terminology                        0.5
# documents_system_architecture                                    0.5
# draws_on_widely_used_system_design_terminology                   0.5
# enables_iterative_system_decomposition                           0.5
# enables_reconciliation_via_postprocessing                        0.7
# facilitates_a_source_of_truth                                    0.5
# facilitates_system_design                                        0.5
# fully_defined                                                    0.8
# fully_designed                                                   0.9
# fully_implemented                                                0.7
# has_a_good_name                                                  0.5
# has_an_mcp_server                                                0.5
# has_good_documentation                                           0.5
# has_good_syntax                                                  0.5
# implements_systems                                               0.5
# is_a_useful_tool                                                 0.5
# is_marketable                                                    0.5
# minimizes_structure_repetition                                   0.5
# no_forbidden_components                                          0.5
# reconciles_user_components                                       0.9
# records_system_architecture                                      0.5
# stores_manifest_data_in_a_useful_format                          0.5
# supports_easy_lookup                                             0.5
# syntax_is_brief                                                  0.5
# syntax_is_flexible                                               0.5
# terminology_is_externally_consistent                             0.5
# terminology_is_internally_consistent                             0.5
# uses_consistent_ecs_terminology                                  0.5
# validates_system_architecture                                    0.5
# works_with_llms_to_implement_systems                             0.5
#
#                                                      requirement.value  \
# entity
# accepts_nested_entities_as_children                iaca_infrastructure
# can_budget_for_preference_and_fit                  iaca_infrastructure
# can_build_delivery_plan                            iaca_infrastructure
# can_build_requirements_map                         iaca_infrastructure
# can_calculate_the_most_efficient_paths             iaca_infrastructure
# can_document_workflows                                             NaN
# can_execute_tests                                                  NaN
# can_incorporate_poorly_formed_components           iaca_infrastructure
# can_perform_registry_etl                                           NaN
# compatible_with_a_config                           iaca_infrastructure
# compliments_existing_agile_approaches              iaca_infrastructure
# directly_calls_agents                              iaca_infrastructure
# documentation_coverage_is_high                  quality_infrastructure
# documentation_quality_is_high                   quality_infrastructure
# documentation_uses_consistent_perspective       quality_infrastructure
# documentation_uses_consistent_terminology       quality_infrastructure
# documents_system_architecture                      iaca_infrastructure
# draws_on_widely_used_system_design_terminology  quality_infrastructure
# enables_iterative_system_decomposition             iaca_infrastructure
# enables_reconciliation_via_postprocessing          iaca_infrastructure
# facilitates_a_source_of_truth                      iaca_infrastructure
# facilitates_system_design                          iaca_infrastructure
# fully_defined                                                      NaN
# fully_designed                                                     NaN
# fully_implemented                                                  NaN
# has_a_good_name                                 quality_infrastructure
# has_an_mcp_server                                  iaca_infrastructure
# has_good_documentation                          quality_infrastructure
# has_good_syntax                                    iaca_infrastructure
# implements_systems                                 iaca_infrastructure
# is_a_useful_tool                                   iaca_infrastructure
# is_marketable                                      iaca_infrastructure
# minimizes_structure_repetition                     iaca_infrastructure
# no_forbidden_components                                            NaN
# reconciles_user_components                         iaca_infrastructure
# records_system_architecture                        iaca_infrastructure
# stores_manifest_data_in_a_useful_format            iaca_infrastructure
# supports_easy_lookup                                               NaN
# syntax_is_brief                                    iaca_infrastructure
# syntax_is_flexible                                 iaca_infrastructure
# terminology_is_externally_consistent            quality_infrastructure
# terminology_is_internally_consistent            quality_infrastructure
# uses_consistent_ecs_terminology                 quality_infrastructure
# validates_system_architecture                      iaca_infrastructure
# works_with_llms_to_implement_systems               iaca_infrastructure
#
#                                                description.comp_key  \
# entity
# accepts_nested_entities_as_children                               0
# can_budget_for_preference_and_fit                                 0
# can_build_delivery_plan                                           0
# can_build_requirements_map                                        0
# can_calculate_the_most_efficient_paths                            0
# can_document_workflows                                            0
# can_execute_tests                                                 0
# can_incorporate_poorly_formed_components                          0
# can_perform_registry_etl                                          0
# compatible_with_a_config                                          0
# compliments_existing_agile_approaches                             0
# directly_calls_agents                                             0
# documentation_coverage_is_high                                    0
# documentation_quality_is_high                                     0
# documentation_uses_consistent_perspective                         0
# documentation_uses_consistent_terminology                         0
# documents_system_architecture                                     0
# draws_on_widely_used_system_design_terminology                    0
# enables_iterative_system_decomposition                            0
# enables_reconciliation_via_postprocessing                         0
# facilitates_a_source_of_truth                                   NaN
# facilitates_system_design                                       NaN
# fully_defined                                                     0
# fully_designed                                                    0
# fully_implemented                                                 0
# has_a_good_name                                                   0
# has_an_mcp_server                                               NaN
# has_good_documentation                                            0
# has_good_syntax                                                 NaN
# implements_systems                                              NaN
# is_a_useful_tool                                                  0
# is_marketable                                                     0
# minimizes_structure_repetition                                    0
# no_forbidden_components                                           0
# reconciles_user_components                                        0
# records_system_architecture                                     NaN
# stores_manifest_data_in_a_useful_format                           0
# supports_easy_lookup                                              0
# syntax_is_brief                                                 NaN
# syntax_is_flexible                                                0
# terminology_is_externally_consistent                              0
# terminology_is_internally_consistent                              0
# uses_consistent_ecs_terminology                                   0
# validates_system_architecture                                     0
# works_with_llms_to_implement_systems                              0
#
#                                                                                 description.value  \
# entity
# accepts_nested_entities_as_children             The files are very hard to follow right now, i...
# can_budget_for_preference_and_fit               The most efficient path isn't necessarily real...
# can_build_delivery_plan                         Given a set of prioritized requirements, can b...
# can_build_requirements_map                      A requirements map is a visual representation ...
# can_calculate_the_most_efficient_paths          Given a set of prioritized requirements, can s...
# can_document_workflows                          iaca must provide functionality to document sy...
# can_execute_tests                               iaca must run all validation tests to verify s...
# can_incorporate_poorly_formed_components        While gathering information it is common to co...
# can_perform_registry_etl                        iaca must perform extract-transform-load opera...
# compatible_with_a_config                        Parameters for iaca should be set in the provi...
# compliments_existing_agile_approaches           There's no way iaca can compete with the level...
# directly_calls_agents                                    Probably want to use langchain for this.
# documentation_coverage_is_high                  A requirement ensuring that most system compon...
# documentation_quality_is_high                   Who is the speaker? What are the technical ter...
# documentation_uses_consistent_perspective       A requirement ensuring documentation maintains...
# documentation_uses_consistent_terminology       A requirement ensuring that technical terms ar...
# documents_system_architecture                   At any given time the code that defines the sy...
# draws_on_widely_used_system_design_terminology                          E.g. the url(s) attached.
# enables_iterative_system_decomposition          The requirements and components of complicated...
# enables_reconciliation_via_postprocessing       After the user defines their yaml, having the ...
# facilitates_a_source_of_truth                                                                 NaN
# facilitates_system_design                                                                     NaN
# fully_defined                                       All [compdef] entities are defined and valid.
# fully_designed                                  Each [requirement] entity has at least one [sa...
# fully_implemented                               Meets the same criteria as "fully_designed" an...
# has_a_good_name                                                    A good name goes a long way.\n
# has_an_mcp_server                                                                             NaN
# has_good_documentation                          A requirement ensuring that the system provide...
# has_good_syntax                                                                               NaN
# implements_systems                                                                            NaN
# is_a_useful_tool                                      Fundamentally, iaca must serve a purpose.\n
# is_marketable                                   It doesn't matter how good the system is if yo...
# minimizes_structure_repetition                  iaca should not require the user to go through...
# no_forbidden_components                         No [error], [todo], or other "forbidden" compo...
# reconciles_user_components                      Users should be able to easily reconcile (de-d...
# records_system_architecture                                                                   NaN
# stores_manifest_data_in_a_useful_format         The format we store the data in facilitates di...
# supports_easy_lookup                            When designing a system in yaml it's essential...
# syntax_is_brief                                                                               NaN
# syntax_is_flexible                              Syntax can be used to describe nearly arbitrar...
# terminology_is_externally_consistent            Are the terms used in iaca consistent with com...
# terminology_is_internally_consistent            For terms defined inside iaca, are they used c...
# uses_consistent_ecs_terminology                 Unfortunately, "system" and "component" are us...
# validates_system_architecture                   iaca must provide a series of automated tests ...
# works_with_llms_to_implement_systems            Reflecting on this, this is low priority becau...
#
#                                                status.comp_key status.value
# entity
# accepts_nested_entities_as_children                        NaN          NaN
# can_budget_for_preference_and_fit                          NaN          NaN
# can_build_delivery_plan                                    NaN          NaN
# can_build_requirements_map                                 NaN          NaN
# can_calculate_the_most_efficient_paths                     NaN          NaN
# can_document_workflows                                     NaN          NaN
# can_execute_tests                                          NaN          NaN
# can_incorporate_poorly_formed_components                   NaN          NaN
# can_perform_registry_etl                                   NaN          NaN
# compatible_with_a_config                                   NaN          NaN
# compliments_existing_agile_approaches                      NaN          NaN
# directly_calls_agents                                      NaN          NaN
# documentation_coverage_is_high                             NaN          NaN
# documentation_quality_is_high                              NaN          NaN
# documentation_uses_consistent_perspective                  NaN          NaN
# documentation_uses_consistent_terminology                  NaN          NaN
# documents_system_architecture                              NaN          NaN
# draws_on_widely_used_system_design_terminology             NaN          NaN
# enables_iterative_system_decomposition                     NaN          NaN
# enables_reconciliation_via_postprocessing                  NaN          NaN
# facilitates_a_source_of_truth                              NaN          NaN
# facilitates_system_design                                  NaN          NaN
# fully_defined                                              NaN          NaN
# fully_designed                                             NaN          NaN
# fully_implemented                                          NaN          NaN
# has_a_good_name                                            NaN          NaN
# has_an_mcp_server                                          NaN          NaN
# has_good_documentation                                     NaN          NaN
# has_good_syntax                                            NaN          NaN
# implements_systems                                         NaN          NaN
# is_a_useful_tool                                           NaN          NaN
# is_marketable                                              NaN          NaN
# minimizes_structure_repetition                             NaN          NaN
# no_forbidden_components                                    NaN          NaN
# reconciles_user_components                                 NaN          NaN
# records_system_architecture                                NaN          NaN
# stores_manifest_data_in_a_useful_format                    NaN          NaN
# supports_easy_lookup                                       NaN          NaN
# syntax_is_brief                                            NaN          NaN
# syntax_is_flexible                                         NaN          NaN
# terminology_is_externally_consistent                       NaN          NaN
# terminology_is_internally_consistent                       NaN          NaN
# uses_consistent_ecs_terminology                            NaN          NaN
# validates_system_architecture                              NaN          NaN
# works_with_llms_to_implement_systems                       NaN          NaN

# %%
reqs["description.sanitized"] = reqs["description.value"].str.replace("\n", " ").str.replace('"', "'")

# %%
def_body = ""
for entity, req in reqs.iterrows():
    def_body += f"requirement {entity} {{"
    if not pd.isna(req["description.sanitized"]):
        def_body += f'\n    text: "{req["description.sanitized"]}"'
    def_body += "\n}\n\n"
print(def_body)
# Out:
# requirement accepts_nested_entities_as_children {
#     text: "The files are very hard to follow right now, in regards to parents and children. Allowing nesting as code works should be both straightforward and greatly improve readability. "
# }
#
# requirement can_budget_for_preference_and_fit {
#     text: "The most efficient path isn't necessarily realistic: people have preferences and are better fits for some tasks than others. "
# }
#
# requirement can_build_delivery_plan {
#     text: "Given a set of prioritized requirements, can build a delivery plan. "
# }
#
# requirement can_build_requirements_map {
#     text: "A requirements map is a visual representation of requirements and the possible routes to complete them. Before deciding on any sort of algorithm, putting the data in a format for people to understand what needs to get done and how it relates comes first. "
# }
#
# requirement can_calculate_the_most_efficient_paths {
#     text: "Given a set of prioritized requirements, can suggest which to do in what order. "
# }
#
# requirement can_document_workflows {
#     text: "iaca must provide functionality to document system workflows and processes."
# }
#
# requirement can_execute_tests {
#     text: "iaca must run all validation tests to verify system requirements are met."
# }
#
# requirement can_incorporate_poorly_formed_components {
#     text: "While gathering information it is common to come across a piece of information that is clearly important, but poorly defined. We need to record such information so it can be defined and incorporated when more is known. "
# }
#
# requirement can_perform_registry_etl {
#     text: "iaca must perform extract-transform-load operations on manifests to create registries."
# }
#
# requirement compatible_with_a_config {
#     text: "Parameters for iaca should be set in the provided manifest."
# }
#
# requirement compliments_existing_agile_approaches {
#     text: "There's no way iaca can compete with the level of features provided by leading Agile software. We need to compliment them. "
# }
#
# requirement directly_calls_agents {
#     text: "Probably want to use langchain for this."
# }
#
# requirement documentation_coverage_is_high {
#     text: "A requirement ensuring that most system components and features are documented."
# }
#
# requirement documentation_quality_is_high {
#     text: "Who is the speaker? What are the technical terms used?"
# }
#
# requirement documentation_uses_consistent_perspective {
#     text: "A requirement ensuring documentation maintains a consistent narrative voice throughout."
# }
#
# requirement documentation_uses_consistent_terminology {
#     text: "A requirement ensuring that technical terms are used consistently across all documentation."
# }
#
# requirement documents_system_architecture {
#     text: "At any given time the code that defines the system must be able to be compiled and turned into a digestable, clear, format. "
# }
#
# requirement draws_on_widely_used_system_design_terminology {
#     text: "E.g. the url(s) attached."
# }
#
# requirement enables_iterative_system_decomposition {
#     text: "The requirements and components of complicated systems are rarely known all at once, but are assembled over time in an iterative process. This process includes gathering functional requirements from the stakeholders, identifying technical requirements/constraints, trial and error, and more. One of the goals of iaca is to provide a constant, living source of truth that can be used for both the formalized design and also components and requirements not yet incorporated. "
# }
#
# requirement enables_reconciliation_via_postprocessing {
#     text: "After the user defines their yaml, having the system postprocess to reconcile and then rewrite would be very helpful. "
# }
#
# requirement facilitates_a_source_of_truth {
# }
#
# requirement facilitates_system_design {
# }
#
# requirement fully_defined {
#     text: "All [compdef] entities are defined and valid."
# }
#
# requirement fully_designed {
#     text: "Each [requirement] entity has at least one [satisfies] entity or one [child] entity. "
# }
#
# requirement fully_implemented {
#     text: "Meets the same criteria as 'fully_designed' and all [satisfies] entities either have a test that passes when executed or have a status of 'in production'. "
# }
#
# requirement has_a_good_name {
#     text: "A good name goes a long way. "
# }
#
# requirement has_an_mcp_server {
# }
#
# requirement has_good_documentation {
#     text: "A requirement ensuring that the system provides clear and comprehensive documentation."
# }
#
# requirement has_good_syntax {
# }
#
# requirement implements_systems {
# }
#
# requirement is_a_useful_tool {
#     text: "Fundamentally, iaca must serve a purpose. "
# }
#
# requirement is_marketable {
#     text: "It doesn't matter how good the system is if you cannot convince anyone to use it. "
# }
#
# requirement minimizes_structure_repetition {
#     text: "iaca should not require the user to go through code and transcribe the structure into yaml when it's already defined. Possible solutions: 1. Automatically retrieve structure from the code. 2. Use the structure in the yaml to define code execution order "
# }
#
# requirement no_forbidden_components {
#     text: "No [error], [todo], or other 'forbidden' components."
# }
#
# requirement reconciles_user_components {
#     text: "Users should be able to easily reconcile (de-duplicate and match formatting) between components they define on the fly and components that already exist, either theirs or in the system. "
# }
#
# requirement records_system_architecture {
# }
#
# requirement stores_manifest_data_in_a_useful_format {
#     text: "The format we store the data in facilitates different applications."
# }
#
# requirement supports_easy_lookup {
#     text: "When designing a system in yaml it's essential that it's easy to find components that may fit. Auto-complete in yaml would be good. "
# }
#
# requirement syntax_is_brief {
# }
#
# requirement syntax_is_flexible {
#     text: "Syntax can be used to describe nearly arbitrary data."
# }
#
# requirement terminology_is_externally_consistent {
#     text: "Are the terms used in iaca consistent with community standards? For example, are the relationships for requirement diagrams sufficiently consistent? "
# }
#
# requirement terminology_is_internally_consistent {
#     text: "For terms defined inside iaca, are they used consistently throughout? "
# }
#
# requirement uses_consistent_ecs_terminology {
#     text: "Unfortunately, 'system' and 'component' are used in two different contexts currently--as part of system design (where components are pieces of a system) and as part of entity-component-system (where components are data). "
# }
#
# requirement validates_system_architecture {
#     text: "iaca must provide a series of automated tests that ensure the system architecture meets requirements. "
# }
#
# requirement works_with_llms_to_implement_systems {
#     text: "Reflecting on this, this is low priority because it's already a very competitive space. Setting up an mcp server is probably a good idea, but calling agents is probably not helpful. "
# }

# %%
links = registry.view("link")
links = links.loc[links["source"].isin(reqs.index) & links["target"].isin(reqs.index)]

# %%
from textwrap import indent

# %%
lines = links["target"] + " - derives -> " + links["source"]

arrow_body = "\n".join(lines)

# %%
mermaid_str = f"""
requirementDiagram

{def_body}

{arrow_body}
"""
print(mermaid_str)
# Out:
# requirementDiagram
#
# requirement accepts_nested_entities_as_children {
#     text: "The files are very hard to follow right now, in regards to parents and children. Allowing nesting as code works should be both straightforward and greatly improve readability. "
# }
#
# requirement can_budget_for_preference_and_fit {
#     text: "The most efficient path isn't necessarily realistic: people have preferences and are better fits for some tasks than others. "
# }
#
# requirement can_build_delivery_plan {
#     text: "Given a set of prioritized requirements, can build a delivery plan. "
# }
#
# requirement can_build_requirements_map {
#     text: "A requirements map is a visual representation of requirements and the possible routes to complete them. Before deciding on any sort of algorithm, putting the data in a format for people to understand what needs to get done and how it relates comes first. "
# }
#
# requirement can_calculate_the_most_efficient_paths {
#     text: "Given a set of prioritized requirements, can suggest which to do in what order. "
# }
#
# requirement can_document_workflows {
#     text: "iaca must provide functionality to document system workflows and processes."
# }
#
# requirement can_execute_tests {
#     text: "iaca must run all validation tests to verify system requirements are met."
# }
#
# requirement can_incorporate_poorly_formed_components {
#     text: "While gathering information it is common to come across a piece of information that is clearly important, but poorly defined. We need to record such information so it can be defined and incorporated when more is known. "
# }
#
# requirement can_perform_registry_etl {
#     text: "iaca must perform extract-transform-load operations on manifests to create registries."
# }
#
# requirement compatible_with_a_config {
#     text: "Parameters for iaca should be set in the provided manifest."
# }
#
# requirement compliments_existing_agile_approaches {
#     text: "There's no way iaca can compete with the level of features provided by leading Agile software. We need to compliment them. "
# }
#
# requirement directly_calls_agents {
#     text: "Probably want to use langchain for this."
# }
#
# requirement documentation_coverage_is_high {
#     text: "A requirement ensuring that most system components and features are documented."
# }
#
# requirement documentation_quality_is_high {
#     text: "Who is the speaker? What are the technical terms used?"
# }
#
# requirement documentation_uses_consistent_perspective {
#     text: "A requirement ensuring documentation maintains a consistent narrative voice throughout."
# }
#
# requirement documentation_uses_consistent_terminology {
#     text: "A requirement ensuring that technical terms are used consistently across all documentation."
# }
#
# requirement documents_system_architecture {
#     text: "At any given time the code that defines the system must be able to be compiled and turned into a digestable, clear, format. "
# }
#
# requirement draws_on_widely_used_system_design_terminology {
#     text: "E.g. the url(s) attached."
# }
#
# requirement enables_iterative_system_decomposition {
#     text: "The requirements and components of complicated systems are rarely known all at once, but are assembled over time in an iterative process. This process includes gathering functional requirements from the stakeholders, identifying technical requirements/constraints, trial and error, and more. One of the goals of iaca is to provide a constant, living source of truth that can be used for both the formalized design and also components and requirements not yet incorporated. "
# }
#
# requirement enables_reconciliation_via_postprocessing {
#     text: "After the user defines their yaml, having the system postprocess to reconcile and then rewrite would be very helpful. "
# }
#
# requirement facilitates_a_source_of_truth {
# }
#
# requirement facilitates_system_design {
# }
#
# requirement fully_defined {
#     text: "All [compdef] entities are defined and valid."
# }
#
# requirement fully_designed {
#     text: "Each [requirement] entity has at least one [satisfies] entity or one [child] entity. "
# }
#
# requirement fully_implemented {
#     text: "Meets the same criteria as 'fully_designed' and all [satisfies] entities either have a test that passes when executed or have a status of 'in production'. "
# }
#
# requirement has_a_good_name {
#     text: "A good name goes a long way. "
# }
#
# requirement has_an_mcp_server {
# }
#
# requirement has_good_documentation {
#     text: "A requirement ensuring that the system provides clear and comprehensive documentation."
# }
#
# requirement has_good_syntax {
# }
#
# requirement implements_systems {
# }
#
# requirement is_a_useful_tool {
#     text: "Fundamentally, iaca must serve a purpose. "
# }
#
# requirement is_marketable {
#     text: "It doesn't matter how good the system is if you cannot convince anyone to use it. "
# }
#
# requirement minimizes_structure_repetition {
#     text: "iaca should not require the user to go through code and transcribe the structure into yaml when it's already defined. Possible solutions: 1. Automatically retrieve structure from the code. 2. Use the structure in the yaml to define code execution order "
# }
#
# requirement no_forbidden_components {
#     text: "No [error], [todo], or other 'forbidden' components."
# }
#
# requirement reconciles_user_components {
#     text: "Users should be able to easily reconcile (de-duplicate and match formatting) between components they define on the fly and components that already exist, either theirs or in the system. "
# }
#
# requirement records_system_architecture {
# }
#
# requirement stores_manifest_data_in_a_useful_format {
#     text: "The format we store the data in facilitates different applications."
# }
#
# requirement supports_easy_lookup {
#     text: "When designing a system in yaml it's essential that it's easy to find components that may fit. Auto-complete in yaml would be good. "
# }
#
# requirement syntax_is_brief {
# }
#
# requirement syntax_is_flexible {
#     text: "Syntax can be used to describe nearly arbitrary data."
# }
#
# requirement terminology_is_externally_consistent {
#     text: "Are the terms used in iaca consistent with community standards? For example, are the relationships for requirement diagrams sufficiently consistent? "
# }
#
# requirement terminology_is_internally_consistent {
#     text: "For terms defined inside iaca, are they used consistently throughout? "
# }
#
# requirement uses_consistent_ecs_terminology {
#     text: "Unfortunately, 'system' and 'component' are used in two different contexts currently--as part of system design (where components are pieces of a system) and as part of entity-component-system (where components are data). "
# }
#
# requirement validates_system_architecture {
#     text: "iaca must provide a series of automated tests that ensure the system architecture meets requirements. "
# }
#
# requirement works_with_llms_to_implement_systems {
#     text: "Reflecting on this, this is low priority because it's already a very competitive space. Setting up an mcp server is probably a good idea, but calling agents is probably not helpful. "
# }
#
#
#
# can_build_delivery_plan - derives -> can_build_requirements_map
# can_build_delivery_plan - derives -> can_calculate_the_most_efficient_paths
# can_build_delivery_plan - derives -> can_budget_for_preference_and_fit
# enables_iterative_system_decomposition - derives -> can_incorporate_poorly_formed_components
# is_a_useful_tool - derives -> compatible_with_a_config
# is_a_useful_tool - derives -> compliments_existing_agile_approaches
# has_good_documentation - derives -> documentation_coverage_is_high
# has_good_documentation - derives -> documentation_quality_is_high
# documentation_quality_is_high - derives -> documentation_uses_consistent_perspective
# documentation_quality_is_high - derives -> documentation_uses_consistent_terminology
# documents_system_architecture - derives -> stores_manifest_data_in_a_useful_format
# is_a_useful_tool - derives -> documents_system_architecture
# terminology_is_externally_consistent - derives -> draws_on_widely_used_system_design_terminology
# facilitates_system_design - derives -> enables_iterative_system_decomposition
# enables_iterative_system_decomposition - derives -> facilitates_a_source_of_truth
# is_a_useful_tool - derives -> facilitates_system_design
# is_marketable - derives -> has_a_good_name
# has_good_syntax - derives -> syntax_is_brief
# has_good_syntax - derives -> syntax_is_flexible
# records_system_architecture - derives -> has_good_syntax
# implements_systems - derives -> works_with_llms_to_implement_systems
# implements_systems - derives -> reconciles_user_components
# is_a_useful_tool - derives -> implements_systems
# is_a_useful_tool - derives -> is_marketable
# reconciles_user_components - derives -> enables_reconciliation_via_postprocessing
# records_system_architecture - derives -> accepts_nested_entities_as_children
# is_a_useful_tool - derives -> records_system_architecture
# documentation_uses_consistent_terminology - derives -> terminology_is_externally_consistent
# documentation_uses_consistent_terminology - derives -> terminology_is_internally_consistent
# terminology_is_internally_consistent - derives -> uses_consistent_ecs_terminology
# is_a_useful_tool - derives -> validates_system_architecture
# works_with_llms_to_implement_systems - derives -> has_an_mcp_server
# works_with_llms_to_implement_systems - derives -> directly_calls_agents

# %%
with open("./sketch.mmd", "w", encoding="utf-8") as f:
    f.write(mermaid_str)

# %%
import base64
import io, requests
from IPython.display import Image, display
from PIL import Image as im
import matplotlib.pyplot as plt

def mm(graph):
    graphbytes = graph.encode("utf8")
    base64_bytes = base64.urlsafe_b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    img = im.open(io.BytesIO(requests.get('https://mermaid.ink/img/' + base64_string).content))
    plt.imshow(img)
    plt.axis('off') # allow to hide axis
    plt.savefig("mermaid.png")

mm(mermaid_str)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[14], line 16
#      13     plt.axis('off') # allow to hide axis
#      14     plt.savefig("mermaid.png")
# ---> 16 mm(mermaid_str)
#
# Cell In[14], line 11, in mm(graph)
#       9 base64_bytes = base64.urlsafe_b64encode(graphbytes)
#      10 base64_string = base64_bytes.decode("ascii")
# ---> 11 img = im.open(io.BytesIO(requests.get('https://mermaid.ink/img/' + base64_string).content))
#      12 plt.imshow(img)
#      13 plt.axis('off') # allow to hide axis
#
# File ~/repos/iaca/.venv/lib/python3.13/site-packages/PIL/Image.py:3560, in open(fp, mode, formats)
#    3558     warnings.warn(message)
#    3559 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3560 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x11b5f68e0>

# %%
# Visualize the graph
nx.draw(registry.graph, with_labels=True)

# %%
import ast

# %%
with open("../iaca/etl.py", "r") as f:
    source = f.read()
tree = ast.parse(source)
tree

# %%
list(ast.iter_child_nodes(tree))

# %%
import ast

# %%
node = ast.parse("""
def my_function(x) -> int:
    return x + 1

x = my_function(5)
""")

# %%
nt = ast.NodeTransformer()
nt.visit(node)

# %%
nt = ast.NodeVisitor()
nt.visit(node)

# %%
list(ast.iter_child_nodes(node.body[1]))

# %%
node.body[1].value.func.ctx

# %%
node.body[0].__class__.__name__

# %%
node.body[0]._fields

# %%
node.body[0].body[0].value._fields

# %%
visitor = ComponentVisitor()

# %%
visitor.visit(tree)

# %%
pd.DataFrame(visitor.components)

# %%
type(tree.body[-1])

# %%
dict(ast.iter_fields(child_node))

# %%
components = []
for child_node in ast.iter_child_nodes(tree.body[-1]):
    comp_i = {
        "component_type": type(child_node).__name__
    }
    components.append(comp_i)

components

# %%
tree.body[-1].__dir__()

# %%
for item in ast.iter_fields(tree.body[-1].body[-1]):
    print(item)

# %%
visitor.visit(tree.body[-1])

# %%
ast.walk(visitor.visit(tree))

# %%
for item in ast.walk(tree):
    print(item)

# %%
visitor.visit_Constant(tree)

# %%
components = {}
for field, value in ast.iter_fields(tree):
    print(field, value)
    if isinstance(value, str)

# %%
for item in ast.iter_child_nodes(transform_sys_tree):
    print(item)

# %%
ast.get_source_segment(source, transform_sys_tree)

# %%
ast.get_docstring(transform_sys_tree)

# %%
isinstance(transform_sys_tree, ast.AST)
